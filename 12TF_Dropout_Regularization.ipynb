# %% [markdown]
# <a href="https://colab.research.google.com/github/amargauge26/dEEPLERSAING..TENSORFLOW_KERES/blob/main/12TF_Dropout_Regularization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("/content/drive/MyDrive/SAMPLE_DATASETS/pandasdtaset/sonar_dataset.csv", header=None)
df.sample(5)
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 136  0.1088  0.1278  0.0926  0.1234  0.1276  0.1731  0.1948  0.4262  0.6828
# 66   0.0265  0.0440  0.0137  0.0084  0.0305  0.0438  0.0341  0.0780  0.0844
# 120  0.0346  0.0509  0.0079  0.0243  0.0432  0.0735  0.0938  0.1134  0.1228
# 28   0.0100  0.0275  0.0190  0.0371  0.0416  0.0201  0.0314  0.0651  0.1896
# 110  0.0210  0.0121  0.0203  0.1036  0.1675  0.0418  0.0723  0.0828  0.0494
#
#          9   ...      51      52      53      54      55      56      57  \
# 136  0.5761  ...  0.0455  0.0213  0.0082  0.0124  0.0167  0.0103  0.0205
# 66   0.0779  ...  0.0038  0.0187  0.0156  0.0068  0.0097  0.0073  0.0081
# 120  0.1508  ...  0.0040  0.0122  0.0107  0.0112  0.0102  0.0052  0.0024
# 28   0.2668  ...  0.0088  0.0104  0.0036  0.0088  0.0047  0.0117  0.0020
# 110  0.0686  ...  0.0117  0.0101  0.0061  0.0031  0.0099  0.0080  0.0107
#
#          58      59  60
# 136  0.0178  0.0187   M
# ...

# %%
df.shape
# check for nan values
df.isna().sum()
df.columns
df[60].value_counts()
# Out:
# 60
# M    111
# R     97
# Name: count, dtype: int64

# %%
X = df.drop(60,axis=1)
y = df[60]
y.head()
# Out:
# 0    R
# 1    R
# 2    R
# 3    R
# 4    R
# Name: 60, dtype: object

# %%
X
# Out:
#          0       1       2       3       4       5       6       7       8   \
# 0    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 203  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 204  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 205  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 206  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 207  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
# ...

# %%
y = pd.get_dummies(y,drop_first=True)
y.sample(5)
# Out:
#          R
# 24    True
# 97   False
# 1     True
# 142  False
# 172  False

# %%
from sklearn.model_selection import  train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=1)

# %%
X_train.shape
# Out:
# (156, 60)

# %%
import tensorflow as tf
from tensorflow import  keras

# %%
model=keras.Sequential([
    keras.layers.Dense(60,input_dim=60,activation="relu"),
    keras.layers.Dense(30,activation="relu"),
    keras.layers.Dense(15,activation="relu"),
    keras.layers.Dense(1,activation="sigmoid"),#binary classification pro
])

# %%
model.compile(optimizer="adam",loss="binary_crossentropy",metrics=["accuracy"])

# %%
model.fit(X_train,y_train,epochs=100,batch_size=8)
# Out:
# Epoch 1/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.4345 - loss: 0.7039
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5366 - loss: 0.6865
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6138 - loss: 0.6486
# Epoch 4/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6720 - loss: 0.6316
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6904 - loss: 0.6229
# Epoch 6/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7198 - loss: 0.5818
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7992 - loss: 0.5578
# Epoch 8/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8263 - loss: 0.5091
# Epoch 9/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8370 - loss: 0.4612
# Epoch 10/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7654 - loss: 0.4840
# Epoch 11/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7792 - loss: 0.4676
# Epoch 12/100
# ...

# %%
model.evaluate(X_test,y_test)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7524 - loss: 1.1695
# [1.0282928943634033, 0.7692307829856873]

# %%
y_pred = model.predict(X_test).reshape(-1)
print(y_pred[:10])

# round the values to nearest integer ie 0 or 1
y_pred = np.round(y_pred)
print(y_pred[:10])
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# [9.6609865e-10 8.9887363e-01 5.7398343e-01 4.5141396e-06 9.9999952e-01
#  9.9995339e-01 2.8499088e-01 9.9999952e-01 6.9881871e-06 9.9999982e-01]
# [0. 1. 1. 0. 1. 1. 0. 1. 0. 1.]

# %%
from sklearn.metrics import classification_report ,confusion_matrix

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.74      0.85      0.79        27
#         True       0.81      0.68      0.74        25
#
#     accuracy                           0.77        52
#    macro avg       0.78      0.77      0.77        52
# weighted avg       0.77      0.77      0.77        52

# %%
modeld = keras.Sequential([
    keras.layers.Dense(60, input_dim=60, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(30, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(15, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1, activation='sigmoid')
])

modeld.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

modeld.fit(X_train, y_train, epochs=100, batch_size=8)
# Out:
# Epoch 1/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.5405 - loss: 0.8015
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4954 - loss: 0.7517
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4641 - loss: 0.7516
# Epoch 4/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5862 - loss: 0.6576
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5517 - loss: 0.7109
# Epoch 6/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5613 - loss: 0.6731
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5626 - loss: 0.6999
# Epoch 8/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5076 - loss: 0.7090
# Epoch 9/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6170 - loss: 0.6397
# Epoch 10/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6174 - loss: 0.6761
# Epoch 11/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5594 - loss: 0.7227
# Epoch 12/100
# ...

# %%
modeld.evaluate(X_test, y_test)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7732 - loss: 0.5095
# [0.49144789576530457, 0.7692307829856873]

# %%
y_pred = modeld.predict(X_test).reshape(-1)
print(y_pred[:10])

# round the values to nearest integer ie 0 or 1
y_pred = np.round(y_pred)
print(y_pred[:10])
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# [9.2544842e-06 6.5627795e-01 8.6599976e-01 4.0476019e-03 9.8896927e-01
#  8.5093689e-01 4.0870884e-01 9.9069291e-01 8.0504734e-03 9.8930007e-01]
# [0. 1. 1. 0. 1. 1. 0. 1. 0. 1.]

# %%
from sklearn.metrics import confusion_matrix , classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.71      0.93      0.81        27
#         True       0.88      0.60      0.71        25
#
#     accuracy                           0.77        52
#    macro avg       0.80      0.76      0.76        52
# weighted avg       0.80      0.77      0.76        52
